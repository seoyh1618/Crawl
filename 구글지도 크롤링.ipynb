# %% [markdown]
# ###### 작성자 : 손해원 , 수정 : 서연호
# ###### 구글지도 장소
# - 검색어 설정 후 순서대로 실행

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from tqdm import tqdm
import pandas as pd
import time

# %%
driver = webdriver.Chrome('C:/dev_python/Webdriver/chromedriver')
# Out:
# <ipython-input-2-4770ba30d060>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/dev_python/Webdriver/chromedriver')

# %% [markdown]
# ##### 검색어 설정

# %%
url = 'https://www.google.com/maps/search/김천숙소' ##### 검색어 설정 
driver.get(url)
driver.maximize_window()

# %% [markdown]
# ##### url 수집

# %%
url_list = []

for x in tqdm(range(10)):# 마지막 페이지 제외 1회당 20개   
    for i in range(25): # 페이지 스크롤 다운 기능 
        driver.find_element_by_class_name('a4gq8e-aVTXAb-haAclf-jRmmHf-hSRGPd').send_keys(Keys.PAGE_DOWN)

    upso_list = driver.find_elements_by_class_name('a4gq8e-aVTXAb-haAclf-jRmmHf-hSRGPd') # 숙박업소 리스트
    
    for j in range(len(upso_list)): # url 스크랩 
        time.sleep(1)
        detail_url = upso_list[j].get_attribute('href')
        url_list.append(detail_url)

    driver.find_element_by_css_selector('#ppdPk-Ej1Yeb-LgbsSe-tJiF1e').click() # 다음 페이지 클릭 
    x+=1

###### 검색 내역이 끝나면 'element click intercepted' 에러 발생 후 종료
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]<ipython-input-4-81575f6e30ee>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name('a4gq8e-aVTXAb-haAclf-jRmmHf-hSRGPd').send_keys(Keys.PAGE_DOWN)
# <ipython-input-4-81575f6e30ee>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   upso_list = driver.find_elements_by_class_name('a4gq8e-aVTXAb-haAclf-jRmmHf-hSRGPd') # 숙박업소 리스트
# <ipython-input-4-81575f6e30ee>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#ppdPk-Ej1Yeb-LgbsSe-tJiF1e').click() # 다음 페이지 클릭
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [03:31<00:23, 23.45s/it]
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-4-81575f6e30ee> in <module>
#      12         url_list.append(detail_url)
#      13
# ---> 14     driver.find_element_by_css_selector('#ppdPk-Ej1Yeb-LgbsSe-tJiF1e').click() # 다음 페이지 클릭
#      15     x+=1
#      16
#
# C:\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self) -> None:
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     691             params = {}
#     692         params['id'] = self._id
# --> 693         return self._parent.execute(command, params)
#     694
#     695     def find_element(self, by=By.ID, value=None):
#
# C:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# C:\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button ved="1i:3,t:12696,e:2,p:oCiMYfjmCIj8wQP-466QDQ:17" aria-label="다음 페이지" id="ppdPk-Ej1Yeb-LgbsSe-tJiF1e" jstcache="273" jsaction="pane.paginationSection.nextPage" class="hV1iCc noprint hV1iCc-disabled" jsan="7.hV1iCc,7.noprint,7.hV1iCc-disabled,0.disabled,0.ved,0.aria-label,0.id,22.jsaction" disabled="true">...</button> is not clickable at point (367, 849). Other element would receive the click: <div class="punXpd">...</div>
#   (Session info: chrome=95.0.4638.69)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B406F3+2492147]
# 	Ordinal0 [0x00AD9BD1+2071505]
# 	Ordinal0 [0x009E2478+1057912]
# 	Ordinal0 [0x00A129F9+1255929]
# 	Ordinal0 [0x00A10D34+1248564]
# 	Ordinal0 [0x00A0EAFD+1239805]
# 	Ordinal0 [0x00A0D958+1235288]
# 	Ordinal0 [0x00A03647+1193543]
# 	Ordinal0 [0x00A257C3+1333187]
# 	Ordinal0 [0x00A03466+1193062]
authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EB%AA%A8%ED%85%94%EC%9C%88/data=!4m8!3m7!1s0x35659812e948d8b1:0x9ba2a116c7af985a!5m2!4m1!1i2!8m2!3d36.1207447!4d128.1282118?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EC%9C%A0%EC%95%A4%EC%95%84%EC%9D%B4%ED%8E%9C%EC%85%98/data=!4m8!3m7!1s0x3565bf6d15d57bd7:0x60a83bc30e350aaf!5m2!4m1!1i2!8m2!3d36.1108533!4d128.3150952?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EC%B9%B8%EB%AA%A8%ED%85%94/data=!4m8!3m7!1s0x3565bdd3c0bf9ce1:0x51db12835ed3f05b!5m2!4m1!1i2!8m2!3d36.1273452!4d128.2266586?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%ED%99%80%EB%A6%AC%EB%8D%B0%EC%9D%B4/data=!4m8!3m7!1s0x3565eab06a8d9fc3:0x8643cfdad4e6207d!5m2!4m1!1i2!8m2!3d36.047035!4d128.32593?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%ED%98%B8%ED%85%94%EA%B8%88%EC%98%A4%EC%82%B0/data=!4m8!3m7!1s0x3565c0a9a539171f:0x37e531a5773d1c01!5m2!4m1!1i2!8m2!3d36.1102125!4d128.3097059?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EB%A6%AC%EC%BD%94%EB%AA%A8%ED%85%94/data=!4m8!3m7!1s0x3565be7f8439f749:0xc70676c66f4bddae!5m2!4m1!1i2!8m2!3d36.1274379!4d128.2329554?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EC%97%90%EC%9D%B4%EB%AA%A8%ED%85%94/data=!4m8!3m7!1s0x3565c732b2cd38d3:0x7c9e05f3e1fede9d!5m2!4m1!1i2!8m2!3d36.123714!4d128.347416?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/Gimcheon+Vitamin+Self+Check-in+Motel/data=!4m8!3m7!1s0x3565830f4999b493:0x24b4d88bf08618d!5m2!4m1!1i2!8m2!3d35.985817!4d128.032593?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EC%9D%B4%EC%BD%94%EB%85%B8%EB%AF%B8%ED%98%B8%ED%85%94+%EA%B5%AC%EB%AF%B8%EC%A0%90/data=!4m8!3m7!1s0x3565c0b4cf1952eb:0xea3ce95b1f55e9dd!5m2!4m1!1i2!8m2!3d36.128264!4d128.334127?authuser=0&hl=ko&rclk=1', 'https://www.google.com/maps/place/%EC%9C%A0%EC%95%A4%EC%95%84%EC%9D%B4%ED%8E ...

# %% [markdown]
# ###### 리뷰 스크랩

# %%
review_list = []
#address = []

for x in tqdm(range(len(url_list))):
    # url로 이동 
    driver.get(url_list[x])
    time.sleep(1)
    
    # 숙박업소주소
    #address_p = driver.find_element_by_css_selector('div.QSFF4-text.gm2-body-2')
    #address.append(address_p.text)
    place = driver.find_element_by_class_name('x3AX1-LfntMc-header-title-title.gm2-headline-5').text
    
    try:
        # 리뷰 더보기 클릭 
        driver.find_element_by_css_selector('#pane > div > div.Yr7JMd-pane-content.cYB2Ge-oHo7ed > div > div > div.x3AX1-LfntMc-header-title > div.x3AX1-LfntMc-header-title-ma6Yeb-haAclf > div.x3AX1-LfntMc-header-title-ij8cu > div.x3AX1-LfntMc-header-title-ij8cu-haAclf > div > div.gm2-body-2.h0ySl-wcwwM-RWgCYc > span:nth-child(3) > span > span > span.OAO0-ZEhYpd-vJ7A6b.OAO0-ZEhYpd-vJ7A6b-qnnXGd > span:nth-child(1) > button').click()
        time.sleep(3)

        try :
            #리뷰 스크롤 진행 
            for i in range(100) : 
                driver.find_element_by_class_name('siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc').send_keys(Keys.PAGE_DOWN)
                
            review_dict = {}
    
            #path 
            
            name_p = driver.find_elements_by_css_selector('div.ODSEW-ShBeI-title')   
            date_p = driver.find_elements_by_css_selector('span.ODSEW-ShBeI-RgZmSc-date-J42Xof-Hjleke > span:nth-child(1)')
            text_p = driver.find_elements_by_css_selector('div.ODSEW-ShBeI-RWgCYc > div > span.ODSEW-ShBeI-text')
            stars_p = driver.find_elements_by_css_selector('span.ODSEW-ShBeI-RGxYjb-wcwwM')
            
            names = []
            dates = []
            texts = []
            stars = []
            
            # text로 변환 
            for index in range(len(name_p)) : 
                names.append(name_p[index].text)
                dates.append(date_p[index].text)
                texts.append(text_p[index].text.replace('\n',' '))   
                stars.append(stars_p[index].text)
                
            review_dict['place'] = place      
            #review_dict['address'] = address            # 주소 추가 
            review_dict['review_cnt'] = len(names) # 리뷰 개수 추가 
            review_dict['writer'] = names
            review_dict['date'] = dates
            review_dict['stars'] = stars           #리뷰별 별점 추가
            review_dict['content'] = texts
            review_dict['url'] = url_list[x]
            
            #print(review_dict)
            
            review_list.append(review_dict)
            
        except:
            continue
    except:
        continue
# Out:
#   0%|                                                                                          | 0/182 [00:00<?, ?it/s]<ipython-input-25-1409032d8c26>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   address_p = driver.find_element_by_css_selector('div.QSFF4-text.gm2-body-2')
# <ipython-input-25-1409032d8c26>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   place = driver.find_element_by_class_name('x3AX1-LfntMc-header-title-title.gm2-headline-5').text
# <ipython-input-25-1409032d8c26>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#pane > div > div.Yr7JMd-pane-content.cYB2Ge-oHo7ed > div > div > div.x3AX1-LfntMc-header-title > div.x3AX1-LfntMc-header-title-ma6Yeb-haAclf > div.x3AX1-LfntMc-header-title-ij8cu > div.x3AX1-LfntMc-header-title-ij8cu-haAclf > div > div.gm2-body-2.h0ySl-wcwwM-RWgCYc > span:nth-child(3) > span > span > span.OAO0-ZEhYpd-vJ7A6b.OAO0-ZEhYpd-vJ7A6b-qnnXGd > span:nth-child(1) > button').click()
# <ipython-input-25-1409032d8c26>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name('siAUzd-neVct.section-scrollbox.cYB2Ge-oHo7ed.cYB2Ge-ti6hGc').send_keys(Keys.PAGE_DOWN)
# <ipython-input-25-1409032d8c26>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_p = driver.find_elements_by_css_selector('div.ODSEW-ShBeI-title')
# <ipython-input-25-1409032d8c26>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   date_p = driver.find_elements_by_css_selector('span.ODSEW-ShBeI-RgZmSc-date-J42Xof-Hjleke > span:nth-child(1)')
# <ipython-input-25-1409032d8c26>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   text_p = driver.find_elements_by_css_selector('div.ODSEW-ShBeI-RWgCYc > div > span.ODSEW-ShBeI-text')
# <ipython-input-25-1409032d8c26>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   stars_p = driver.find_elements_by_css_selector('span.ODSEW-ShBeI-RGxYjb-wcwwM')
# 100%|████████████████████████████████████████████████████████████████████████████████| 182/182 [28:50<00:00,  9.51s/it]

# %%
#review_df.rename(columns={'restaurant':'place'}, inplace=True)

# %%
review_df = pd.DataFrame(review_list)

# %%
review_df.tail(20)
# Out:
#                                   place  \
# 76                                 코아모텔
# 77                                시드니모텔
# 78                                클래식모텔
# 79                                  쉘모텔
# 80                               라온제나펜션
# 81                       달의정원(한옥스테이,카페)
# 82                                 구월모텔
# 83                                양지장모텔
# 84                                  샵모텔
# 85                                하와이모텔
# 86                                 엘비모텔
# 87          Seongju Green Narae Pension
# 88                                 올인모텔
# 89                                 제이모텔
# 90                               비취파크모텔
# 91                                 윤슬펜션
# 92                                모텔금강산
# 93                              뉴아테네힐모텔
# 94                          별밤 펜션 오토캠핑장
# 95  Jeungsan Sudo Valley Camping Resort
#
#                                               address  review_cnt  \
# 76  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           8
# 77  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           6
# 78  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           8
# 79  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           1
# 80  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           3
# 81  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...          53
# 82  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           4
# 83  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           1
# 84  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...          16
# 85  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           5
# 86  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           8
# 87  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           8
# 88  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           4
# 89  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           3
# 90  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...          13
# 91  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           4
# 92  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           1
# 93  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           2
# 94  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...          40
# 95  [경상북도 김천시 혁신 2로 10 KR, 69-3 Aratjangteo-gil, 자...           1
#
#                                                writer  \
# 76    [최영현, 김두현, tiger슝, 최연충, Ralff T, 김정한, 김한우, 장성훈]
# 77                     [권순창, 김숙경, 고형재, 김진곤, 김영진, 이경철]
# 78  [배경재, 유쉘김정태, Jonghun Kim, Min Seo, 최정미, 센스마스터 ...
# 79                           [아마버스커-최성운 (아마 버스커 노가리)]
# 80                              [j mook, 로아의이야기, 이상식]
# 81  [e- Tube, Eric Park, 김상범, 김춘화, 양진아, 삼족오, Mad H...
# 82                               [신재학, 카이, 신유식, 몰봐따샤]
# 83                                       [hyunsu kim]
# 84  [Dinyong N, FX KAZ, 서연, Daejong Lee, H Lee, 궁서...
# 85                          [이상은, 차재근, 이태석, 임성규, 조은래]
# 86  [Cent “ioi” Hi, 정호, 주상건, 황수영, 김동진, 양승기, 양선규, N...
# 87  [양철중, 오베러, 이주식, 티타임, Green-김은령, kyle Kim, Denn...
# 88                    [정록향, 손명락, Sujeung Kim, Type R]
# 89                [강신원, Waegook Travel, 장윤석 (슬픈거친인생)]
# 90  [그냥 !!떳다 황, 둥이기록실, mandoo, 입과음식의 첫만남, Erlan Sa...
# 91                                 [아귀, 윤짱, 유수환, 김승영]
# 92                                              [이경엽]
# 93                                      [Kei Do, 정석태]
# 94  [연금술사, 박유진, 윤여주, Jongrae Kim, 최ᄋᄀ, 오세준, 모에모에큥,...
# 95               [Gibs Rivera (The Incredibert Gibs)]
#
#                                                  date  \
# 76   [4년 전, 4년 전, 3년 전, 3년 전, 3년 전, 3년 전, 3년 전, 3년 전]
# 77               [3년 전, 5년 전, 3년 전, 3년 전, 2년 전, 2년 전]
# 78  [10달 전, 3년 전, 4년 전, 1년 전, 3년 전, 2년 전, 1년 전, 4년 전]
# 79                                             [2년 전]
# 80                                 [3주 전, 4달 전, 1년 전]
# 81  [1달 전, 2달 전, 1달 전, 5달 전, 3달 전, 1달 전, 2달 전, 5달 ...
# 82                           [1달 전, 3년 전, 2년 전, 2년 전]
# 83                                             [2년 전]
# 84  [3년 전, 3년 전, 3년 전, 3년 전, 3년 전, 8달 전, 2년 전, 3년 ...
# 88  [시설은 좀 낙후되었으나 주인 내외가 친절하고 가급적 불편 사항을 해결하려고 노력한...
# 89  [보통의 모텔, (Google 번역 제공) 잘 위치해 있습니다. 돈을 위해 좋은 가...
# 90  [가을인데 환기 ㅠㅠㅠ 너무 더워요 온도조절 없음, 금액이 저럼하고 장기방 추천 합...
# 91  [정말 나만 알고싶은 곳.. 무조건 여긴 다시올수밖에없다. 에어컨은 켤생각도못할정도...
# 92                                         [방도크고 좋아요]
# 93                                            [안가봄, ]
# 94  [오늘 가족과  답사갔더니   참  좋아요 조만간방문할께요, 조용하고 한적하고 사장...
# 95  [(Google 번역 제공) 증산 워터 밸리 캠핑 장입니다. 그 장소는 산 때문에 ...
#
#                                                   url
# 76  https://www.google.com/maps/place/%EC%BD%94%EC...
# 77  https://www.google.com/maps/place/%EC%8B%9C%EB...
# 78  https://www.google.com/maps/place/%ED%81%B4%EB...
# 79  https://www.google.com/maps/place/%EC%89%98%EB...
# 80  https://www.google.com/maps/place/%EB%9D%BC%EC...
# 81  https://www.google.com/maps/place/%EB%8B%AC%EC...
# 82  https://www.google.com/maps/place/%EA%B5%AC%EC...
# 83  https://www.google.com/maps/place/%EC%96%91%EC...
# 84  https://www.google.com/maps/place/%EC%83%B5%EB...
# 85  https://www.google.com/maps/place/%ED%95%98%EC...
# 86  https://www.google.com/maps/place/%EC%97%98%EB...
# 87  https://www.google.com/maps/place/Seongju+Gree...
# 88  https://www.google.com/maps/place/%EC%98%AC%EC...
# 89  https://www.google.com/maps/place/%EC%A0%9C%EC...
# 90  https://www.google.com/maps/place/%EB%B9%84%EC...
# 91  https://www.google.com/maps/place/%EC%9C%A4%EC...
# 92  https://www.google.com/maps/place/%EB%AA%A8%ED...
# 93  https://www.google.com/maps/place/%EB%89%B4%EC...
# 94  https://www.google.com/maps/place/%EB%B3%84%EB...
# 95  https://www.google.com/maps/place/Jeungsan+Sud...

# %%
review_df.to_csv('C:/Users/seoyeonho/Desktop/Crawler_csv/googlemaps_1111_김천숙소(200).csv', index=False)

# %%
revide_df = review_df.drop(['address'],axis=1)

# %%
revide_df
# Out:
#                                   place  review_cnt  \
# 0                                로제니아호텔         130
# 1                              김천 호텔 이상          32
# 2                       Gimcheon Milano           1
# 3                                김천파크호텔         130
# 4                                몽플러스모텔           3
# ..                                  ...         ...
# 91                                 윤슬펜션           4
# 92                                모텔금강산           1
# 93                              뉴아테네힐모텔           2
# 94                          별밤 펜션 오토캠핑장          40
# 95  Jeungsan Sudo Valley Camping Resort           1
#
#                                                writer  \
# 0   [워렌파파, Hyoungyong kim, 김정아, 정명모, EDWARD KIM, 최...
# 1   [박영진새우랑, JOUNG WOOK KWON, 코코G, 후라이드광팬, 김서현, 김영...
# 2                                               [김재식]
# 3   [윤석희, K SM (hmm), 배동석, daddy PARK, Hyung-Ki Pa...
# 4   [Orchid Shin (Dong-Wook), S.Antonio Lim, Jayso...
# ..                                                ...
# 91                                 [아귀, 윤짱, 유수환, 김승영]
# 92                                              [이경엽]
# 93                                      [Kei Do, 정석태]
# 94  [연금술사, 박유진, 윤여주, Jongrae Kim, 최ᄋᄀ, 오세준, 모에모에큥,...
# 95               [Gibs Rivera (The Incredibert Gibs)]
#
#                                                  date  \
# 0   [1주 전, 1달 전, 2달 전, 1달 전, 2달 전, 2달 전, 3주 전, 2달 ...
# 1   [1달 전, 5달 전, 2달 전, 2주 전, 4달 전, 4달 전, 1년 전, 11달...
# 2                                              [2달 전]
# 3   [1주 전, 7달 전, 5달 전, 4달 전, 6달 전, 5달 전, 11달 전, 1년...
# 4                                 [4달 전, 7달 전, 11달 전]
# ..                                                ...
# 91                           [3달 전, 8달 전, 3년 전, 3달 전]
# 92                                             [9년 전]
# 93                                       [4년 전, 3년 전]
# 94  [2달 전, 7달 전, 7달 전, 1년 전, 1년 전, 2년 전, 2년 전, 2년 ...
# 95                                            [11달 전]
#
#                                                 stars  \
# 0   [5/5, 3/5, 4/5, 4/5, 3/5, 1/5, 4/5, 4/5, 1/5, ...
# 1   [5/5, 4/5, 5/5, 5/5, 3/5, 3/5, 5/5, 5/5, 2/5, ...
# 2                                               [3/5]
# 3   [3/5, 5/5, 2/5, 4/5, 4/5, 3/5, 3/5, 5/5, 3/5, ...
# 4                                     [3/5, 1/5, 5/5]
# ..                                                ...
# 91                               [5/5, 2/5, 1/5, 5/5]
# 92                                              [4/5]
# 93                                         [3/5, 4/5]
# 94  [5/5, 5/5, 4/5, 5/5, 5/5, 4/5, 3/5, 5/5, 5/5, ...
# 95                                              [5/5]
#
#                                               content  \
# 0   [김천 포도CC  원정때 묵었던 숙소! 주위에 식당도 많고 깨끗하게  잘 쉬다옴, ...
# 1   [시설좋고. 깔끔하고. 좋아요. 가격은 대실3만. 숙박8만원 입니다., 깨끗한 모텔...
# 2                                                  []
# 3   [리모탤링 빨리해야 겠네요, 일때문에 4일 묵었는데 호텔 가는 길에 핀 벚꽃 개나리...
# 4   [가격은 싸지만 청결은 그닥., 가격은 싼 곳 b.u.t., (Google 번역 제...
# ..                                                ...
# 91  [정말 나만 알고싶은 곳.. 무조건 여긴 다시올수밖에없다. 에어컨은 켤생각도못할정도...
# 92                                         [방도크고 좋아요]
# 93                                            [안가봄, ]
# 94  [오늘 가족과  답사갔더니   참  좋아요 조만간방문할께요, 조용하고 한적하고 사장...
# 95  [(Google 번역 제공) 증산 워터 밸리 캠핑 장입니다. 그 장소는 산 때문에 ...
#
#                                                   url
# 0   https://www.google.com/maps/place/%EB%A1%9C%EC...
# 1   https://www.google.com/maps/place/%EA%B9%80%EC...
# 2   https://www.google.com/maps/place/Gimcheon+Mil...
# 3   https://www.google.com/maps/place/%EA%B9%80%EC...
# 4   https://www.google.com/maps/place/%EB%AA%BD%ED...
# ..                                                ...
# 91  https://www.google.com/maps/place/%EC%9C%A4%EC...
# 92  https://www.google.com/maps/place/%EB%AA%A8%ED...
# 93  https://www.google.com/maps/place/%EB%89%B4%EC...
# 94  https://www.google.com/maps/place/%EB%B3%84%EB...
# 95  https://www.google.com/maps/place/Jeungsan+Sud...
#
# [96 rows x 7 columns]

# %%
review_df.to_csv('C:/Users/seoyeonho/Desktop/Crawler_csv/googlemaps_1111_김천숙소(200)_주소삭제.csv', index=False)
