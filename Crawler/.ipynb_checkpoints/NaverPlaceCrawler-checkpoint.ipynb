# %% [markdown]
# ### NaverPlaces Crawler
# ### 작성자 : 서연호
# * 수집 가능 데이터
#       name = []
#       address = []
#       geo = []                   # 위도, 경도
#       siteUrl = []
#       lodgingCategory = []       # 숙박 분류
#       roomType = []              # 방종류
#       priceRange = []            # 가격
#       description = []
#       aggregate_rating = []
#       reviewids = []             # Review 문서 id
#       postingids = []            # posting 문서 id
#       facility = []              # 시설 정보
#       telephone = []             # 연락 전화
#       mageUrl = []              # 숙박업체 images url
# * 수집 불가 데이터
#       tourUrl = []               # 관광지 권역
#       administrativeDong = []    # 행정동
#       star_rating = []           # ( n 성급 호텔)
#       officalRating = []         # 숙박 공식 등급 (모범업소 등)
#       lastUpdate = []            # 최근 갱신일
#       event = []                 # 이벤트 ( 숙박 할인 , 숙박지행사 )

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import NoSuchElementException                    
from tqdm import tqdm
import time
import pandas as pd
import googlemaps

# %%
driver_path = 'C:/dev_python/Webdriver/chromedriver'
query = '김천여관'                                     
url = 'https://www.naver.com'
gmaps_key = 'AIzaSyDFFxNTBDX-ii1yPntiKPmV-uN1TTcwRJE'  #google api키 입력

# %%
driver = webdriver.Chrome(driver_path)
driver.get(url)
driver.implicitly_wait(3)
#driver.maximize_window()
# Out:
# <ipython-input-58-5ef4fe65933b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)

# %% [markdown]
# ### Naver Home -> Query Search

# %%
# Query Search
driver.find_element(By.ID,'query').send_keys(query)
driver.find_element(By.ID,'search_btn').click()

# %% [markdown]
# ### Place Click

# %%
time.sleep(2)
driver.find_element(By.CSS_SELECTOR,'#place-app-root div.api_more_wrap').click()

# %% [markdown]
# ## frame  변경
# * naver -> map.naver.com

# %%
print(driver.current_url)
driver.switch_to.window(driver.window_handles[1])
print(driver.current_url)

element = driver.find_element(By.XPATH,'//*[@id="searchIframe"]') 
driver.switch_to.frame(element)
# Out:
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EA%B9%80%EC%B2%9C%EC%97%AC%EA%B4%80
# https://map.naver.com/v5/search/%EA%B9%80%EC%B2%9C%EC%97%AC%EA%B4%80

# %% [markdown]
# ## DataList

# %%
reviewids = []           # Review 문서 id 
postingids = []            # posting 문서 id

# %%
# NaverPlace 수집 가능 데이터 정의
dataSource = 'NaverPlace'
name = []             
address = []
siteUrl = [] 
lodgingCategory = []       # 숙박 분류 
description = []  
telephone = []             # 연락 전화
aggregate_rating = []      
geo = []                   # 위도, 경도 
roomType = []              # 방종류 , 가격 , 방 옵션 
imageUrl = []              # 숙박업체 images url    
administrativeDong = []    # 행정동   

#priceRange = []            # roomType에 dict 형태로 가격 포함 되어 있어 미포함

# %%
# NaverPlace 수집 불가 데이터 정의 
event = None                 # 이벤트 ( 숙박 할인 , 숙박지행사 ) 
tourArea = None               # 관광지 권역    -> 직지사, 등등                                             
facility = None              # 시설 정보 
lastUpdate = None            # 최근 갱신일                       
star_rating = None           # ( n 성급 호텔)                    
officalRating = None         # 숙박 공식 등급 (모범업소 등)

# %% [markdown]
# ## Data_PATH

# %%
name_p = '#_title > span._3XamX'
address_p = 'ul > li._1M_Iz._1aj6- > div'
siteUrl_p = 'div.place_detail_wrapper > div:nth-child(4) > div > div > div > ul > li.iSlFU._2reeS > div > div > a'
lodgingCategory_p = '#_title > span._3ocDE'   
priceRange_p = 'li._1M_Iz._1nfcX > div > ul > li > div > div._2O0eV'
description_more_p = 'li._1M_Iz._3__3i > div > a > span.WoYOw'  
description_nomore_p = 'div > ul > li._1M_Iz._3__3i > div > div > span.WoYOw'
aggregate_rating_p = '#app-root > div > div > div.place_detail_wrapper > div.place_section.no_margin.GCwOh > div > div > div._3XpyR._2z4r0 > div > span._1Y6hi._1A8_M > em'           
facility_p = 'li._1M_Iz > div._1h3B_'
telephone_p = 'div._1h3B_ >span:nth-child(1)'

# %% [markdown]
# ### 매장정보 크롤링

# %%
scroll = driver.find_element_by_class_name('_1Az1K')
next_page_p = '#app-root > div > div > div._2ky45 > a:nth-child(3)'
detail_info_p = '#_pcmap_list_scroll_container > ul > li > div._3ZU00 > a:nth-child(1)'
#'#_pcmap_list_scroll_container > ul > li > div.kqlfc > a' # 펜션
# '#_pcmap_list_scroll_container > ul > li > div._3ZU00._1rBq3 > a:nth-child(1)' // 숙박 , 숙소 . 모텔
#_pcmap_list_scroll_container > ul > li > div._3ZU00 > a:nth-child(1) #여관
# page_number-1 까지 크롤링 
page_number = 4

for index in tqdm(range(1,page_number)) : 

    # 스크롤 내리기 
    for scl_location in range(1,10) : 
        driver.execute_script("arguments[0].scrollBy(0, 1300)", scroll)
        time.sleep(0.2) 
    
    # 장소 이름 클릭하면 상세 보기 페이지로 이동 -> 클릭정보 가져오기
    time.sleep(1)
    detail_info_url = driver.find_elements(By.CSS_SELECTOR,detail_info_p)     
    
    #Start Crawling
    for index in range(len(detail_info_url)) : 
        detail_info_url[index].click()
        
        
        #Frame 변경 < Place_Detail_info  >
        time.sleep(1)
        driver.switch_to.window(driver.window_handles[1])
        detail_info_frame = driver.find_element(By.ID,'entryIframe') 
        driver.switch_to.frame(detail_info_frame)
        
        
        #매장명 크롤링
        try : 
            name_t = driver.find_element(By.CSS_SELECTOR,name_p)
            name.append(name_t.text)
        except :
            name.append(None)
            
            
        #매장 주소 크롤링
        try :
            address_t = driver.find_element(By.CSS_SELECTOR,address_p)
            address_str = address_t.text
            address.append(address_str)
        except : 
            address.append(None)
            
        #행정동 크롤링
        try :
            administrativeDong_t = address_str.split('김천시')[1].strip().split(' ')[0]
            administrativeDong.append(administrativeDong_t)
        except :
            administrativeDong.append(None)
        
        
        #위도 경도 저장
        gmaps=googlemaps.Client(key = gmaps_key)

        #한국 위도 경도 최소, 최댓값 정의
        max_lat = 38.0
        min_lat = 33.0
        max_lng = 132.0
        min_lng = 126.0
        
        geo_list = []
        
        try :
            tmp = gmaps.geocode(address_str, language = "ko")
            
            if tmp :
                tmp_loc = tmp[0].get("geometry")
                tmp_lat = tmp_loc["location"]["lat"]
                tmp_lng = tmp_loc["location"]["lng"]
        
                if (tmp_lat > max_lat or tmp_lat < min_lat or tmp_lng > max_lng or tmp_lng < min_lng):
                    geo_list.append("0")
                    geo_list.append("0")
                else :
                    geo_list.append(tmp_lat)
                    geo_list.append(tmp_lng)
            else :
                geo_list.append("0")
                geo_list.append("0")
        except :
            geo_list.append("0")
            geo_list.append("0")
            
        geo.append(geo_list)
            
            
        #홈페이지 주소 크롤링
        try : 
            siteUrl_t = driver.find_element(By.CSS_SELECTOR,siteUrl_p)
            siteUrl.append(siteUrl_t.get_attribute('href'))
        except:
            siteUrl.append(None)
          
        
        #매장 설명 크롤링
        try : 
            # 펼처보기가 있는 경우 
            driver.find_element(By.CSS_SELECTOR,'div.place_section.no_margin > div > ul > li._1M_Iz._3__3i > div > a > span.dX2wL > svg').click()             
            time.sleep(0.5)
            description_t = driver.find_element(By.CSS_SELECTOR,description_more_p)
            
            description.append(description_t.text.replace("\n"," "))  
        except :
            # 펼처보기가 없는 경우 
            try :
                description_t = driver.find_element(By.CSS_SELECTOR,description_nomore_p)
                description.append(description_t.text.replace("\n"," "))
            except :
                description.append(None)
        
        
        #매장 전화 번호 크롤링
        try : 
            telephone_t = driver.find_element(By.CSS_SELECTOR,telephone_p)
            telephone.append(telephone_t.text)
        except :
            telephone.append(None)
        
        
        #매장 분류 크롤링 (모텔 , 호텔 등등)
        try : 
            lodgingCategory_t = driver.find_element(By.CSS_SELECTOR,lodgingCategory_p)
            lodgingCategory.append(lodgingCategory_t.text)
        except :
            lodgingCategory.append(None)
                
                
        #별점 크롤링
        try : 
            aggregate_rating_t = driver.find_element(By.CSS_SELECTOR,aggregate_rating_p)
            aggregate_rating.append(aggregate_rating_t.text)
        except :
            aggregate_rating.append(None)
        
        
        #객실 정보 크롤링 
        #dict 형태로 저장 roomType = [  {방이름 , 가격 , 방설명} , ,'''   ]
        
        try :
            #객실 더보기 클릭
            driver.find_element(By.CSS_SELECTOR,'#app-root > div > div > div.place_detail_wrapper > div > div > div.place_section._3mkep > div._2kAri > a').click()
            time.sleep(1)
        
            roomName_t =[]
            roomPrice_t = []
            roomDescript_t = []
            room_dict = {}
                
            roomName = driver.find_elements(By.CSS_SELECTOR,'div.place_section._1gjmL > div > ul > li > a > div._1Tcwx > div._29WF6 > div > span')
            roomPrice = driver.find_elements(By.CSS_SELECTOR,'div.place_section._1gjmL > div > ul > li > a > div._1Tcwx > div._2QlZz > span.FSeNw')
            roomDescript = driver.find_elements(By.CSS_SELECTOR,'div.place_section._1gjmL > div > ul > li > a > div._1Tcwx > div._33Hep')
            
            for i in range(len(roomName)) :
                try :
                    roomName_t.append(roomName[i].text)
                except :
                    roomName_t.append(None)
                try :
                    roomPrice_t.append(roomPrice[i].text)
                except :
                    roomPrice_t.append(None)
                try :
                    roomDescript_t.append(roomDescript[i].text)
                except :
                    roomDescript_t.append(None)
                        
            room_dict['roomName'] = roomName_t
            room_dict['roomPrice'] = roomPrice_t
            room_dict['roomDescription'] = roomDescript_t
            
            roomType.append(room_dict)
        except :
            roomType.append(None)
        
        #이미지 url 
        try :
            #이미지 더보기 클릭
            driver.find_element(By.CSS_SELECTOR,'#_autoPlayable').click()
            #driver.implicitly_wait(3)
            time.sleep(1)
            images = driver.find_elements(By.CSS_SELECTOR,'ul._3TiO6._1wsFm > li._2OSze > a > img')
           
            images_t = []
            
            for img_index in range(len(images)) :
                images_t.append(images[img_index].get_attribute('src'))
            
            imageUrl.append(images_t)
        except :
            imageUrl.append(None)
        
        
        
        
        #5개만 확인
        #element_check_var = len(detail_info_url) - 5 
        
        #if element_check_var == index :
        #    for i in range(element_check_var-5,element_check_var) :
        ## Insert Check
        print('-------------------------')
        print('name : ',name[index])
        print('administratorDong',administrativeDong[index])
        print('lodgingCategory : ',lodgingCategory[index])
        print('telephone : ',telephone[index])
        print('address : ',address[index])
        print('siteUrl : ',siteUrl[index])
        print('description : ',description[index])
        print('aggregate_rating',aggregate_rating[index])
        print('roomType : ',roomType[index])
        print('geo :',geo[index])
        print('images :',imageUrl[index])
        
        time.sleep(1)
        
        #Frame 변경 < Search_List_Place >
        time.sleep(1)
        driver.switch_to.window(driver.window_handles[1])
        back_frame = driver.find_element(By.ID,'searchIframe') 
        driver.switch_to.frame(back_frame)
        
    driver.find_element(By.CSS_SELECTOR,next_page_p).click()# Next Page Click
# Out:
# <ipython-input-66-98880fde629c>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   scroll = driver.find_element_by_class_name('_1Az1K')
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# -------------------------
# name :  호박여관
# administratorDong 평화중앙6길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙6길 21
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1222237, 128.1139458]
# images : None
# -------------------------
# name :  엘림장여관
# administratorDong 평화중앙2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙2길 2
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1229802, 128.1126826]
# images : None
# -------------------------
# name :  로미오여관
# administratorDong 아랫장터2길
# lodgingCategory :  여관
# telephone :  054-435-2231
# address :  경북 김천시 아랫장터2길 71
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1226269, 128.1296102]
# images : None
# -------------------------
# name :  파크장여관
# administratorDong 평화7길
# lodgingCategory :  여관
# telephone :  054-430-1212
# address :  경북 김천시 평화7길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1249621, 128.1087961]
# images : None
# -------------------------
# name :  삼원장여관
# administratorDong 평화9길
# lodgingCategory :  여관
# telephone :  054-432-7588
# address :  경북 김천시 평화9길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247786, 128.1093902]
# images : None
# -------------------------
# name :  서림장사우나여관
# administratorDong 자래밭골길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 자래밭골길 15
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1170678, 128.1234848]
# images : None
# -------------------------
# name :  제주파크장
# administratorDong 평화길
# lodgingCategory :  여관
# telephone :  054-430-6999
# address :  경북 김천시 평화길 39
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247491, 128.1090702]
# images : None
# -------------------------
# name :  힐튼장여관
# administratorDong 영남대로
# lodgingCategory :  여관
# telephone :  054-430-6763
# address :  경북 김천시 영남대로 2076
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1152901, 128.1548513]
# images : None
# -------------------------
# name :  백운장여관
# administratorDong 평화5길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화5길 22
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1259202, 128.1087207]
# images : None
# -------------------------
# name :  하이파크장
# administratorDong 부곡시장1길
# lodgingCategory :  여관
# telephone :  054-433-5888
# address :  경북 김천시 부곡시장1길 38
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1258798, 128.1055622]
# images : None
# -------------------------
# name :  강남장여관
# administratorDong 황산3길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 황산3길 17
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1160363, 128.1331851]
# images : None
# -------------------------
# name :  홍일장여관
# administratorDong 평화길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화길 123
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1231312, 128.1130906]
# images : None
# -------------------------
# name :  신진장여관
# administratorDong 모암행복2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 모암행복2길 32
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1200303, 128.1261822]
# images : None
# -------------------------
# name :  성수장여관
# administratorDong 문화1길
# lodgingCategory :  여관
# telephone :  054-432-4828
# address :  경북 김천시 문화1길 40
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1270409, 128.1083734]
# images : None
# -------------------------
# name :  혜림장여관
# administratorDong 평화중앙8길
# lodgingCategory :  여관
# telephone :  054-432-1202
# address :  경북 김천시 평화중앙8길 8
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1222816, 128.1145946]
# images : None
# -------------------------
# name :  실버홈
# administratorDong 황산3길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 황산3길 55
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.116674, 128.1310756]
# images : None
# -------------------------
# name :  영남여관
# administratorDong 평화중앙2길
# lodgingCategory :  여관
# telephone :  054-434-2128
# address :  경북 김천시 평화중앙2길 6
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1228208, 128.1125391]
# images : None
# -------------------------
# name :  롯데장여관
# administratorDong 평화7길
# lodgingCategory :  여관
# telephone :  054-433-6563
# address :  경북 김천시 평화7길 13
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1253648, 128.1089655]
# images : None
# -------------------------
# name :  수정여관
# administratorDong 평화중앙6길
# lodgingCategory :  여관
# telephone :  054-434-2764
# address :  경북 김천시 평화중앙6길 29-1
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1217677, 128.1138262]
# images : None
# -------------------------
# name :  제일파크모텔
# administratorDong 부곡시장1길
# lodgingCategory :  여관
# telephone :  054-432-4001
# address :  경북 김천시 부곡시장1길 30
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1256331, 128.1052697]
# images : None
# -------------------------
# name :  반도장
# administratorDong 평화중앙7길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙7길 37
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1215566, 128.1159167]
# images : None
# -------------------------
# name :  정금장여관
# administratorDong 가산2길
# lodgingCategory :  여관
# telephone :  054-432-8367
# address :  경북 김천시 가산2길 14
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1145618, 128.1247794]
# images : None
# -------------------------
# name :  천일여관
# administratorDong 대항면
# lodgingCategory :  여관
# telephone :  054-436-6038
# address :  경북 김천시 대항면 황학동길 13
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1147816, 128.0166332]
# images : None
# -------------------------
# name :  리베라장여관
# administratorDong 자산로
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 자산로 115
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1208863, 128.1193972]
# images : None
# -------------------------
# name :  동원여인숙
# administratorDong 평화시장2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화시장2길 5
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1233992, 128.1117445]
# images : None
# -------------------------
# name :  청운여관
# administratorDong 아랫장터2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 아랫장터2길 67
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.12247190000001, 128.1295811]
# images : None
# -------------------------
# name :  한강파크장
# administratorDong 부곡중앙길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 부곡중앙길 6-9
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1245245, 128.1031597]
# images : None
# -------------------------
# name :  반도여관
# administratorDong 백옥길
# lodgingCategory :  여관
# telephone :  054-434-3336
# address :  경북 김천시 백옥길 5
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1253448, 128.0807951]
# images : None
# -------------------------
# name :  강변장여관
# administratorDong 황산3길
# lodgingCategory :  여관
# telephone :  054-436-0031
# address :  경북 김천시 황산3길 55
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.116674, 128.1310756]
# images : []
# -------------------------
# name :  코리아장여관
# administratorDong 문화1길
# lodgingCategory :  여관
# telephone :  054-439-3449
# address :  경북 김천시 문화1길 10-1
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1267945, 128.1076576]
# images : None
# -------------------------
# name :  유정장여관
# administratorDong 강변로
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 강변로 76
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1184173, 128.1292256]
# images : None
# -------------------------
# name :  부산장여관
# administratorDong 대항면
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 대항면 황학동길 27-3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1150294, 128.0169487]
# images : None
# -------------------------
# name :  핑크장여관
# administratorDong 아랫장터3길
# lodgingCategory :  여관
# telephone :  054-434-0006
# address :  경북 김천시 아랫장터3길 34
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1213971, 128.1291494]
# images : None
# -------------------------
# name :  경일장여관
# administratorDong 중앙공원1길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 중앙공원1길 17-5
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1197158, 128.1199853]
# images : None
# -------------------------
# name :  금호장여관
# administratorDong 충효길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 충효길 14
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1218984, 128.1193821]
# images : None
# -------------------------
# name :  유좌여인숙
# administratorDong 평화중앙4길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙4길 6
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1224864, 128.1125409]
# images : None
# -------------------------
# name :  청운장
# administratorDong 아랫장터2길
# lodgingCategory :  여관
# telephone :  054-434-4741
# address :  경북 김천시 아랫장터2길 67
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.12247190000001, 128.1295811]
# images : None
# -------------------------
# name :  태야여인숙
# administratorDong 평화중앙길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙길 20-3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1228128, 128.1114337]
# images : None
# -------------------------
# name :  나비야모텔
# administratorDong 시민로
# lodgingCategory :  모텔
# telephone :  054-433-6182
# address :  경북 김천시 시민로 3
# siteUrl :  None
# description :  최고의 친절과 서비스로 여러분을 모십니다.
# aggregate_rating None
# roomType :  None
# geo : [36.124534, 128.1036763]
# images : ['https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_34%2F1440991705933yXwSL_JPEG%2F11877722_0.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_242%2F1440991706182HRXeJ_JPEG%2F11877722_1.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_86%2F1440991706343NK7sN_JPEG%2F11877722_2.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_37%2F1440991706531YIPk7_JPEG%2F11877722_3.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_197%2F14409917067201nVQ7_JPEG%2F11877722_4.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_1%2F1440991706895l2hi8_JPEG%2F11877722_5.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_158%2F1440991707089BMF8g_JPEG%2F11877722_6.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_226%2F1440991707320ae93L_JPEG%2F11877722_7.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_272%2F1440991707467e3XbM_JPEG%2F11877722_8.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20180801_244%2F1533054328194kOQm5_JPEG%2F708e6a7fd4f284d5e224c929ff76e9be.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20180801_238%2F1533054328037G7HE9_JPEG%2F26e7fc3a382026feb1b6d44b285c9d77.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20180801_19%2F1533054328012Ytq4q_JPEG%2Ff78c3a4b1ac61f9ff2877b8cf53484f7.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20180801_158%2F1533054328466qaom5_JPEG%2Fb8c89f2c2419ef5ad0b150b5eb78489c.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20180801_271%2F1533054328081RpUdV_JPEG%2F5aeb69b44cc76e6982484a78cebf4713.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_255%2F1589919490568HKAHR_JPEG%2F599ecf57ec3320.12782779.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_52%2F1589919496122Bs5Jf_JPEG%2F599ecf582e1f35.71015926.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_195%2F1589919499347C3zsc_JPEG%2F599ecf586eae62.28775153.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_262%2F1589919485769cmzzI_JPEG%2F599ecf58ab9ec9.12624860.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_44%2F1589919486712IFtvv_JPEG%2F599ecf58ebf181.89727919.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_17%2F1589919496949acjV1_JPEG%2F599ecf59359cd0.66760753.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20200520_278%2F15899194997372NnBx_JPEG%2F599ecf55d1b628.16208826.jpg', 'https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f180_180&src= ...
# -------------------------
# name :  노보텔모텔
# administratorDong 강변로
# lodgingCategory :  모텔
# telephone :  054-434-5180
# address :  경북 김천시 강변로 26
# siteUrl :  None
# description :  주차장 완비되어 있는 최신 시설의 김천 최고의 모텔로서 탁 트인 조망이 자랑입니다. 맑은 공기와 탁 트인 전망, 조용한 환경, 깨끗한 시설로 편안한 휴식처를 약속 드립니다.
# aggregate_rating None
# roomType :  None
# geo : [36.1226951, 128.1298847]
# images : None
# -------------------------
# name :  모텔하이야트
# administratorDong 문화1길
# lodgingCategory :  모텔
# telephone :  054-439-9933
# address :  경북 김천시 문화1길 10-7
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1267771, 128.1079987]
# images : None
# -------------------------
# name :  영빈장여관
# administratorDong 송설로
# lodgingCategory :  모텔
# telephone :  None
# address :  경북 김천시 송설로 173
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1243026, 128.1034504]
# images : None
# -------------------------
# name :  청미장
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-481-2046
# address :  경북 구미시 선산읍 남문로3길 4-3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.2411185, 128.3009967]
# images : None
# -------------------------
# name :  추풍령여관
# administratorDong None
# lodgingCategory :  여관
# telephone :  043-742-2606
# address :  충북 영동군 추풍령면 추풍령로 472
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.2118378, 127.9992571]
# images : None
# -------------------------
# name :  대성여관
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-933-2027
# address :  경북 성주군 성주읍 성주읍3길 6-1
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9185819, 128.2872324]
# images : None
# -------------------------
# name :  로얄장여관
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-933-6685
# address :  경북 성주군 성주읍 성밖숲길 91
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9142756, 128.2859892]
# images : None
# -------------------------
# name :  경북장여관
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-931-1238
# address :  경북 성주군 초전면 대장길 76
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9715038, 128.2643989]
# images : None
# -------------------------
# name :  서울여관
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-933-3119
# address :  경북 성주군 성주읍 성주로 3233-1
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9182277, 128.2875902]
# images : []
# -------------------------
# name :  초원장
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-932-8210
# address :  경북 성주군 초전면 대장길 89-17
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9727341, 128.2631678]
# images : None
# -------------------------
# name :  낙원산장
# administratorDong None
# lodgingCategory :  여관
# telephone :  054-933-6312
# address :  경북 성주군 선남면 성주로 3478-29
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [35.9153834, 128.3113443]
# images : None
#  33%|███████████████████████████▎                                                      | 1/3 [19:35<39:10, 1175.33s/it]
# -------------------------
# name :  호박여관
# administratorDong 평화중앙6길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙6길 21
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1222237, 128.1139458]
# images : None
# -------------------------
# name :  엘림장여관
# administratorDong 평화중앙2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙2길 2
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1229802, 128.1126826]
# images : None
# -------------------------
# name :  로미오여관
# administratorDong 아랫장터2길
# lodgingCategory :  여관
# telephone :  054-435-2231
# address :  경북 김천시 아랫장터2길 71
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1226269, 128.1296102]
# images : None
# -------------------------
# name :  파크장여관
# administratorDong 평화7길
# lodgingCategory :  여관
# telephone :  054-430-1212
# address :  경북 김천시 평화7길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1249621, 128.1087961]
# images : None
# -------------------------
# name :  삼원장여관
# administratorDong 평화9길
# lodgingCategory :  여관
# telephone :  054-432-7588
# address :  경북 김천시 평화9길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247786, 128.1093902]
# images : None
# -------------------------
# name :  서림장사우나여관
# administratorDong 자래밭골길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 자래밭골길 15
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1170678, 128.1234848]
# images : None
# -------------------------
# name :  제주파크장
# administratorDong 평화길
# lodgingCategory :  여관
# telephone :  054-430-6999
# address :  경북 김천시 평화길 39
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247491, 128.1090702]
# images : None
# -------------------------
# name :  힐튼장여관
# administratorDong 영남대로
# lodgingCategory :  여관
# telephone :  054-430-6763
# address :  경북 김천시 영남대로 2076
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1152901, 128.1548513]
# images : None
# -------------------------
# name :  백운장여관
# administratorDong 평화5길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화5길 22
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1259202, 128.1087207]
# images : None
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [22:42<09:53, 593.97s/it]
# -------------------------
# name :  호박여관
# administratorDong 평화중앙6길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙6길 21
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1222237, 128.1139458]
# images : None
# -------------------------
# name :  엘림장여관
# administratorDong 평화중앙2길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화중앙2길 2
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1229802, 128.1126826]
# images : None
# -------------------------
# name :  로미오여관
# administratorDong 아랫장터2길
# lodgingCategory :  여관
# telephone :  054-435-2231
# address :  경북 김천시 아랫장터2길 71
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1226269, 128.1296102]
# images : None
# -------------------------
# name :  파크장여관
# administratorDong 평화7길
# lodgingCategory :  여관
# telephone :  054-430-1212
# address :  경북 김천시 평화7길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1249621, 128.1087961]
# images : None
# -------------------------
# name :  삼원장여관
# administratorDong 평화9길
# lodgingCategory :  여관
# telephone :  054-432-7588
# address :  경북 김천시 평화9길 3
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247786, 128.1093902]
# images : None
# -------------------------
# name :  서림장사우나여관
# administratorDong 자래밭골길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 자래밭골길 15
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1170678, 128.1234848]
# images : None
# -------------------------
# name :  제주파크장
# administratorDong 평화길
# lodgingCategory :  여관
# telephone :  054-430-6999
# address :  경북 김천시 평화길 39
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1247491, 128.1090702]
# images : None
# -------------------------
# name :  힐튼장여관
# administratorDong 영남대로
# lodgingCategory :  여관
# telephone :  054-430-6763
# address :  경북 김천시 영남대로 2076
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1152901, 128.1548513]
# images : None
# -------------------------
# name :  백운장여관
# administratorDong 평화5길
# lodgingCategory :  여관
# telephone :  None
# address :  경북 김천시 평화5길 22
# siteUrl :  None
# description :  None
# aggregate_rating None
# roomType :  None
# geo : [36.1259202, 128.1087207]
# images : None
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [25:43<00:00, 514.63s/it]

# %%
print(len(name))            
print(len(address))
print(len(siteUrl))
print(len(lodgingCategory))
print(len(description))  
print(len(telephone))           
print(len(aggregate_rating))
print(len(geo))      
print(len(roomType))             
print(len(imageUrl))
# Out:
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68

# %% [markdown]
# ### DataFrame

# %%
naverPlace_df = pd.DataFrame({
    'dataSource' : 'NaverPlace',
    'name' : name,            
    'address' : address,
    'geo' : geo,
    'siteUrl' : siteUrl,
    'tourArea' : None,                                   
    'administrativeDong' :administrativeDong, 
    'lodgingCategory' : lodgingCategory,        
    'roomType' : roomType,             
    'description' : description,  
    'aggregate_rating' : aggregate_rating,      
    'star_rating' : None,      
    'officalRating' : None,        
    'facility' : None,             
    'lastUpdate': None,                                
    'telephone' : telephone,            
    'imageUrl' : imageUrl,                
    'event': None
})

# %%
naverPlace_df.head(10)
# Out:
#    dataSource      name           address                        geo siteUrl  \
# 0  NaverPlace      호박여관  경북 김천시 평화중앙6길 21  [36.1222237, 128.1139458]    None
# 1  NaverPlace     엘림장여관   경북 김천시 평화중앙2길 2  [36.1229802, 128.1126826]    None
# 2  NaverPlace     로미오여관  경북 김천시 아랫장터2길 71  [36.1226269, 128.1296102]    None
# 3  NaverPlace     파크장여관     경북 김천시 평화7길 3  [36.1249621, 128.1087961]    None
# 4  NaverPlace     삼원장여관     경북 김천시 평화9길 3  [36.1247786, 128.1093902]    None
# 5  NaverPlace  서림장사우나여관   경북 김천시 자래밭골길 15  [36.1170678, 128.1234848]    None
# 6  NaverPlace     제주파크장     경북 김천시 평화길 39  [36.1247491, 128.1090702]    None
# 7  NaverPlace     힐튼장여관  경북 김천시 영남대로 2076  [36.1152901, 128.1548513]    None
# 8  NaverPlace     백운장여관    경북 김천시 평화5길 22  [36.1259202, 128.1087207]    None
# 9  NaverPlace     하이파크장  경북 김천시 부곡시장1길 38  [36.1258798, 128.1055622]    None
#
#   tourArea administrativeDong lodgingCategory roomType description  \
# 0     None             평화중앙6길              여관     None        None
# 1     None             평화중앙2길              여관     None        None
# 2     None             아랫장터2길              여관     None        None
# 3     None               평화7길              여관     None        None
# 4     None               평화9길              여관     None        None
# 5     None              자래밭골길              여관     None        None
# 6     None                평화길              여관     None        None
# 7     None               영남대로              여관     None        None
# 8     None               평화5길              여관     None        None
# 9     None             부곡시장1길              여관     None        None
#
#   aggregate_rating star_rating officalRating facility lastUpdate  \
# 0             None        None          None     None       None
# 1             None        None          None     None       None
# 2             None        None          None     None       None
# 3             None        None          None     None       None
# 4             None        None          None     None       None
# 5             None        None          None     None       None
# 6             None        None          None     None       None
# 7             None        None          None     None       None
# 8             None        None          None     None       None
# 9             None        None          None     None       None
#
#       telephone imageUrl event
# 0          None     None  None
# 1          None     None  None
# 2  054-435-2231     None  None
# 3  054-430-1212     None  None
# 4  054-432-7588     None  None
# 5          None     None  None
# 6  054-430-6999     None  None
# 7  054-430-6763     None  None
# 8          None     None  None
# 9  054-433-5888     None  None

# %% [markdown]
# ### TO_CSV

# %%
file_name = 'naverPlace김천여관'
file_path = 'C:/Users/seoyeonho/Desktop/ERC_LAB/'

naverPlace_df.to_csv('{}{}.csv'.format(file_path,file_name))

# %% [markdown]
# ### TO_READ

# %%
pd.read_csv('{}{}.csv'.format(file_path,file_name)).head(7)
# Out:
#    Unnamed: 0  dataSource      name           address  \
# 0           0  NaverPlace      호박여관  경북 김천시 평화중앙6길 21
# 1           1  NaverPlace     엘림장여관   경북 김천시 평화중앙2길 2
# 2           2  NaverPlace     로미오여관  경북 김천시 아랫장터2길 71
# 3           3  NaverPlace     파크장여관     경북 김천시 평화7길 3
# 4           4  NaverPlace     삼원장여관     경북 김천시 평화9길 3
# 5           5  NaverPlace  서림장사우나여관   경북 김천시 자래밭골길 15
# 6           6  NaverPlace     제주파크장     경북 김천시 평화길 39
#
#                          geo siteUrl  tourArea administrativeDong  \
# 0  [36.1222237, 128.1139458]     NaN       NaN             평화중앙6길
# 1  [36.1229802, 128.1126826]     NaN       NaN             평화중앙2길
# 2  [36.1226269, 128.1296102]     NaN       NaN             아랫장터2길
# 3  [36.1249621, 128.1087961]     NaN       NaN               평화7길
# 4  [36.1247786, 128.1093902]     NaN       NaN               평화9길
# 5  [36.1170678, 128.1234848]     NaN       NaN              자래밭골길
# 6  [36.1247491, 128.1090702]     NaN       NaN                평화길
#
#   lodgingCategory roomType description  aggregate_rating  star_rating  \
# 0              여관      NaN         NaN               NaN          NaN
# 1              여관      NaN         NaN               NaN          NaN
# 2              여관      NaN         NaN               NaN          NaN
# 3              여관      NaN         NaN               NaN          NaN
# 4              여관      NaN         NaN               NaN          NaN
# 5              여관      NaN         NaN               NaN          NaN
# 6              여관      NaN         NaN               NaN          NaN
#
#    officalRating  facility  lastUpdate     telephone imageUrl  event
# 0            NaN       NaN         NaN           NaN      NaN    NaN
# 1            NaN       NaN         NaN           NaN      NaN    NaN
# 2            NaN       NaN         NaN  054-435-2231      NaN    NaN
# 3            NaN       NaN         NaN  054-430-1212      NaN    NaN
# 4            NaN       NaN         NaN  054-432-7588      NaN    NaN
# 5            NaN       NaN         NaN           NaN      NaN    NaN
# 6            NaN       NaN         NaN  054-430-6999      NaN    NaN

# %% [markdown]
# ## 김천숙박 Data ALL Join

# %%
temp1 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천_게스트하우스.csv')
temp2 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천모텔.csv')
temp3 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천숙박.csv')
temp4 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천숙소.csv')
temp5 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천여관.csv')
temp6 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천펜션.csv')
temp7 = pd.read_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace김천호텔.csv')

# %%
result = pd.concat([temp1,temp2,temp3,temp4,temp5,temp6,temp7],axis=0)

# %%
result.drop_duplicates(['address'])
# Out:
#     Unnamed: 0  dataSource        name  \
# 0            0  NaverPlace   블러썸게스트하우스
# 1            1  NaverPlace          휴가
# 2            2  NaverPlace   무주인게스트하우스
# 3            3  NaverPlace     약목하이호스텔
# 4            4  NaverPlace        달의정원
# ..         ...         ...         ...
# 15          15  NaverPlace      선산관광호텔
# 17          17  NaverPlace        다녀오개
# 18          18  NaverPlace     Best애견샵
# 19          19  NaverPlace  개키우는여자 봉곡점
# 21          21  NaverPlace     위드독스애견샵
#
#                                               address  \
# 0                            경북 김천시 김산향교길 7 블러썸게스트하우스
# 1                               경북 김천시 구성면 월계3길 17-66
# 2   전북 무주군 설천면 구천동1로 150 주소 : 전북 무주군 설천면 구천동1로 150...
# 3                                경북 칠곡군 약목면 약목로 75-12
# 4                          경남 합천군 가야면 치인1길 13-31 달의정원
# ..                                                ...
# 15                               경북 구미시 선산읍 선산대로 1408
# 17                                경북 구미시 봉곡서로 54 다녀오개
# 18                              경북 구미시 봉곡북로 82 베스트애견샵
# 19                       경북 구미시 봉곡로14길 19-4 개키우는여자봉곡점
# 21                                경북 성주군 성주읍 성주로 3232
#
#                           geo                                    siteUrl  \
# 0   [36.1389174, 128.0964937]                                        NaN
# 1   [36.0201514, 127.9794371]              http://blog.naver.com/mee5912
# 2   [35.8993394, 127.7757603]                   http://www.mujuingh.com/
# 3   [36.0330379, 128.3653427]            https://blog.naver.com/jka98191
# 4   [35.7903537, 128.0875102]                   http://dalsgarden.co.kr/
# ..                        ...                                        ...
# 15  [36.2401843, 128.3043853]                                        NaN
# 17    [36.15525, 128.3067563]               https://danyeoogae.modoo.at/
# 18  [36.1538855, 128.3129778]            http://blog.naver.com/minsu0522
# 19  [36.1513283, 128.3164983]  https://www.instagram.com/groomer_kim.sy/
# 21  [35.9179439, 128.2871526]            https://blog.naver.com/withdoch
#
#     tourArea administrativeDong lodgingCategory  \
# 0        NaN              김산향교길          게스트하우스
# 1        NaN                구성면              민박
# 2        NaN                NaN          게스트하우스
# 3        NaN                NaN          게스트하우스
# 4        NaN                NaN            전통숙소
# ..       ...                ...             ...
# 15       NaN                NaN              호텔
# 17       NaN                NaN            애견카페
# 18       NaN                NaN          반려동물미용
# 19       NaN                NaN          반려동물미용
# 21       NaN                NaN          반려동물미용
#
#                                              roomType  \
# 0   {'roomName': ['103', '102', '101'], 'roomPrice...
# 1                                                 NaN
# 2   {'roomName': ['1인실 싱글룸', '2인실 트윈룸', '3인실 온돌룸',...
# 3   {'roomName': ['도미토리(남자공동객실)', '도미토리(여자공동객실)', ...
# 4                                                 NaN
# ..                                                ...
# 15                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#                                           description  aggregate_rating  \
# 0   2016년에 오픈한 김천1호 블러썸게스트하우스입니다. 김천을 방문하시는 모든 분들께...               NaN
# 1   촌스러움의 편안함이 머뭄과 동시에 힐링!! 가만히 머물기만해도 치유가 되는 마당에는...               NaN
# 2   구천동계곡 옆 덕유산 등산로 입구에 위치한 2015년 신축 게스트하우스입니다. 1인...              4.54
# 3             출장 및 여행자를 위한 게스트하우스. 일반숙박업소, 친구와 가족여행추천              4.56
# 4   전통한옥숙박,해인사 주변 한옥스테이를 이용할수 있는 달의정원입니다. 하루숙박 저렴한...              4.53
# ..                                                ...               ...
# 15                                                NaN               NaN
# 17                                                NaN              4.75
# 18  저의 Best 애견샵은 반려견들의 이쁜 모습과 건강함을 소중하게 생각하며 고객님들의...               NaN
# 19                                                NaN               NaN
# 21  성주군 성주읍에 위치한 위드독스 애견샵 입니다. 애견미용, 애견호텔, 애견용품, 애...               NaN
#
#     star_rating  officalRating  facility  lastUpdate       telephone  \
# 0           NaN            NaN       NaN         NaN   010-3813-6318
# 1           NaN            NaN       NaN         NaN  0507-1411-8595
# 2           NaN            NaN       NaN         NaN  0507-1328-9955
# 3           NaN            NaN       NaN         NaN   010-6640-2519
# 4           NaN            NaN       NaN         NaN    055-934-0107
# ..          ...            ...       ...         ...             ...
# 15          NaN            NaN       NaN         NaN    054-482-0225
# 17          NaN            NaN       NaN         NaN  0507-1371-7477
# 18          NaN            NaN       NaN         NaN   010-8504-2852
# 19          NaN            NaN       NaN         NaN  0507-1409-8988
# 21          NaN            NaN       NaN         NaN    054-932-6020
#
#                                              imageUrl  event
# 0   ['https://search.pstatic.net/common/?autoRotat...    NaN
# 1   ['https://search.pstatic.net/common/?autoRotat...    NaN
# 2   ['https://search.pstatic.net/common/?autoRotat...    NaN
# 3   ['https://search.pstatic.net/common/?autoRotat...    NaN
# 4   ['https://search.pstatic.net/common/?autoRotat...    NaN
# ..                                                ...    ...
# 15  ['https://search.pstatic.net/common/?autoRotat...    NaN
# 17  ['https://search.pstatic.net/common/?autoRotat...    NaN
# 18  ['https://search.pstatic.net/common/?autoRotat...    NaN
# 19  ['https://search.pstatic.net/common/?autoRotat...    NaN
# 21  ['https://search.pstatic.net/common/?autoRotat...    NaN
#
# [303 rows x 19 columns]

# %%
result.to_csv('C:/Users/seoyeonho/Desktop/ERC_LAB/Data/김천숙박/naverPlace숙박.csv')
